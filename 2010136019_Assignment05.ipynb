# %% [markdown]
# |과목명|스크립트 프로그래밍|
# |-|-|
# |학번|2010136019|
# |이름|김동현|
# |제출일자|14.12.13|

# %% [markdown]
# ## 1. 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# 클래스와 모듈은 정의된 항목을 캡슐화하는 참조 형식이지만 다른 프로시저에서 항목을 엑세스하는 방법이 서로 다릅니다. 또한 클래스는 인스턴스화가 가능하지만 모듈은 그렇지 않습니다.

# %% [markdown]
# ## 2. 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %%
class sports:
    def using_ball(self):
        print '해당 종목에서 사용하는 공'
    
class baseball(sports):
    def using_ball(self):
        print '야구공'

class football(sports):
    def using_ball(self):
        print '축구공'
        
class basketball(sports):
    def using_ball(self):
        print '농구공'
    
class tennis(sports):
    def using_ball(self):
        print '테니스공'
        
for ele in (baseball(), football(), basketball(), tennis()):
    ele.using_ball();
# Out:
# 야구공
# 축구공
# 농구공
# 테니스공

# %% [markdown]
# ## 3. 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %%
class Counter:
    def __init__(self, _count, _step=1):
        self.count=_count
        self.step=_step
    def __str__(self):
        return '[Count(step:' + str(self.step) + ')] ' + str(self.count)
    def incr(self):
        self.count+=self.step
    def __call__(self):
        self.incr()
    def __add__(self, other):
        return self.count+other
    def __sub__(self, other):
        return self.count-other
    def __cmp__(self, other):
        if self.count>=other:
            return true
        else:
            return false

c = Counter(10)
d = Counter(10,2)

print c
print d

c.incr()
d.incr()
print c
print d

c()
d()

print c
print d

c = c + 5
d = d - 5
print c
print d

print c > 10
print d > 10
print c < 10
print d < 10
print c == 17
print d != 9
# Out:
# [Count(step:1)] 10
# [Count(step:2)] 10
# [Count(step:1)] 11
# [Count(step:2)] 12
# [Count(step:1)] 12
# [Count(step:2)] 14
# 17
# 9
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ## 4. 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.

# %%
class MySet(list):
    def __init__(self, l): #생성자
        for e in l: #'l'이라는 리스트를 입력받아서 그 원소들을 새로운 클래스 Myset의 메소드로 사용합니다.
            self.append(e)
        MySet.eliminate_duplicate(self) #미리 생성되있던 스태틱 메소드를 불러온다. 
    
    def __str__(self): #__str()__메소드
        result = "MySet: {"
        for e in self: #class MySet의 메소드 l을 형식에 맞추어 출력한다.
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod #static method는 class가 선언되기 전에도 사용할 수 있다.(미리 메모리에 load되어 있다.)   
    def eliminate_duplicate(l):
        s = [] #s 리스트 초기화
        for e in l: 
            if e not in s: #l리스트에서 원소들을 중복없이 s리스트에 저장한다.(ex. aaabbc -> abc) / 임시저장의 개념
                s.append(e)
        l[:] = [] #l 리스트 초기화
        for e in s: #s리스트의 모든 원소를 l리스트로 옮긴다.(즉, class Myset의 멤버가 된다.)
            l.append(e)
    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# ## 5. 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)

# %%
class MySet(list):
    def __init__(self, l): #생성자
        for e in l: #'l'이라는 리스트를 입력받아서 그 원소들을 새로운 클래스 Myset의 메소드로 사용합니다.
            self.append(e)
        MySet.eliminate_duplicate(self) #미리 생성되있던 스태틱 메소드를 불러온다. 
    
    def __str__(self): #__str()__메소드
        result = "MySet: {"
        for e in self: #class MySet의 메소드 l을 형식에 맞추어 출력한다.
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    def __or__(self, other):
        return self+other
    def __and__(self, other):
        result=[]
        for ele in self:
            if ele in other:
                result.append(ele)
        return result
    def __sub__(self, other):
        result=[]
        for ele in self:
            if ele not in self&other:
                result.append(ele)
        return result
    
    @staticmethod #static method는 class가 선언되기 전에도 사용할 수 있다.(미리 메모리에 load되어 있다.)   
    def eliminate_duplicate(l):
        s = [] #s 리스트 초기화
        for e in l: 
            if e not in s: #l리스트에서 원소들을 중복없이 s리스트에 저장한다.(ex. aaabbc -> abc) / 임시저장의 개념
                s.append(e)
        l[:] = [] #l 리스트 초기화
        for e in s: #s리스트의 모든 원소를 l리스트로 옮긴다.(즉, class Myset의 멤버가 된다.)
            l.append(e)
    
    
    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
    
    s = s|t
    print s
    
    s = MySet([1,2,3])
    t = MySet([3,4,5])
    s = s&t
    print s
    
    s = MySet([1,2,3])
    t = MySet([3,4,5])
    s = s - t
    print s
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# [1, 2, 3, 2, 3, 4, 5, 6, 7, 8, 9]
# [3]
# [1, 2]

# %% [markdown]
# ## 6. 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %%
class MySet(list):
    def __init__(self, l): #생성자
        for e in l: #'l'이라는 리스트를 입력받아서 그 원소들을 새로운 클래스 Myset의 메소드로 사용합니다.
            self.append(e)
        MySet.eliminate_duplicate(self) #미리 생성되있던 스태틱 메소드를 불러온다. 
    
    def __str__(self): #__str()__메소드
        result = "MySet: {"
        for e in self: #class MySet의 메소드 l을 형식에 맞추어 출력한다.
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    def __or__(self, other):
        return self+other
    def __and__(self, other):
        result=[]
        for ele in self:
            if ele in other:
                result.append(ele)
        return result
    def __sub__(self, other):
        result=[]
        for ele in self:
            if ele not in self&other:
            #if ele not in __add__(other):
                result.append(ele)
        return result
    
    @staticmethod #static method는 class가 선언되기 전에도 사용할 수 있다.(미리 메모리에 load되어 있다.)   
    def eliminate_duplicate(l):
        s = [] #s 리스트 초기화
        for e in l: 
            if e not in s: #l리스트에서 원소들을 중복없이 s리스트에 저장한다.(ex. aaabbc -> abc) / 임시저장의 개념
                s.append(e)
        l[:] = [] #l 리스트 초기화
        for e in s: #s리스트의 모든 원소를 l리스트로 옮긴다.(즉, class Myset의 멤버가 된다.)
            l.append(e)
        
if __name__ == "__main__":
    s = MySet([1,2,3,4,5,6])
    
    print len(s)
    
    print bool(s)
    
    print 2 in s
# Out:
# 6
# True
# True

# %% [markdown]
# 이유 : MySet 클래스가 부모 클래스 list의 메소드 len(), bool(), in 등을 물려 받았기 때문이다.(부모 클래스에 정의된 메소드를 참조함)

# %% [markdown]
# ## 7. 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3과 Assignment 4를 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.

# %%
import urllib
import re #특수문자 제거를 위함

class WebWordsFrequency(list):
    dic={} #각 단어들의 출현빈도를 사전형태로 저장
    
    def __init__(self, *args):
        for ele in args:
            self.append(ele)
    def addUrl(self, url):
        self.append(url)
    def removeUrl(self, url):
        i = self.index(url) #url이 가장 먼저 나오는 인덱스 값
        self = self[:i]+self[i:]
    def listUrls(self):
        for ele in self:
            print ele
            
    #@staticmethod
    def getWordsFrequency(self):        
        if self!=None:
            for url in self:
                source = urllib.urlopen(url).read()
                len_source = len(source)

                source_new = None
                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                        found = True;
                        j = i + 7;
                        while (True):
                            if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                                #print "found - script"
                                source = source[:i] + ' ' + source[j+9:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                len_source = len(source)

                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                        found = True;
                        j = i + 6;
                        while (True):
                            if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                                #print "found - style"
                                source = source[:i] + ' ' + source[j+8:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                len_source = len(source)

                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<"):
                        found = True;
                        j = i + 1;
                        while (True):
                            if (source[j] == ">"):
                                #print "found - HTML tag"
                                source = source[:i] + ' ' + source[j+1:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                words = source.split()
                
                for word in words:
                    word=re.sub('[^가-힝0-9a-zA-Z\\s]', '', word) #특수문자 제거
                    if word!='':
                        if(dic.get(word) == None):
                            dic[word] = 1
                        else:
                            dic[word] += 1
        print dic

    def getMaxFrequencyWords(self):
        max_keys=[] #value가 가장 큰 키값의 모임
        L=dic.items() #사전의 items 저장
        L.sort(reverse=True, key=lambda item:item[1]) #value값에 따라 오름차순으로 정렬
        for ele in L:
            if ele[1]==L[0][1]:
                max_keys.append(ele[0]) #내림차순 정렬을 하였으므로 첫 번째 인자가 가장 크다. 
            else: #더이상 L[0]와 같은 값이 없으면 종료
                break
        for ele in max_keys:
            print ele    

w1=WebWordsFrequency('http://www.nbviewer.org', 'http://www.amazon.com', 'http://www.apple.com')
w2=WebWordsFrequency('http://www.nbviewer.org', 'http://www.amazon.com')
w3=WebWordsFrequency('http://www.nbviewer.org')

w1.addUrl('http://www.bbc.com')
w2.addUrl('http://www.fcc.gov')

w1.removeUrl('http://www.nbviewer.org')
w2.removeUrl('http://www.amazon.com')

w1.listUrls()

w1.getWordsFrequency()

print 

w1.getMaxFrequencyWords()
w2.getMaxFrequencyWords()
# Out:
# http://www.nbviewer.org
# http://www.amazon.com
# http://www.apple.com
# http://www.bbc.com
# {'\xe1\x80\x96\xe1\x80\xbd\xe1\x80\x84\xe1\x80\xba\xe1\x80\xb7\xe1\x80\x9c\xe1\x80\xbe\xe1\x80\x85\xe1\x80\xba': 1, 'Improvement': 4, 'Dining': 1, '6pm': 1, 'Kyrgyz': 1, 'eligible': 1, 'Watch': 5, 'Harimau': 1, 'under': 1, 'Cases': 2, 'League': 1, 'updated': 1, 'risk': 2, 'every': 2, 'GB': 1, 'reforms': 1, 'Todays': 2, 'Parametric': 1, 'IJulia': 1, 'Premier': 1, 'Go': 1, 'clothes': 1, 'enjoy': 1, 'pindah': 1, 'budget': 1, 'Available': 2, 'Culture': 2, 'Amazon': 40, 'new': 5, 'ever': 3, 'Bigger': 1, 'wwwamazoncomaccess': 1, 'Made': 3, 'Items': 4, 'affiliates': 1, 'governing': 1, '100': 1, 'Theres': 2, 'kids': 1, 'auction': 1, 'items': 2, 'employees': 1, 'Queen': 1, 'guide': 3, 'credit': 1, 'Home': 14, 'golden': 1, 'Privacy': 3, 'Support': 1, 'Relations': 1, 'Also': 1, 'Book': 3, 'Health': 8, 'plot': 1, 'Star': 1, '24176C': 2, 'chargers': 2, 'Newsstand': 2, 'music': 4, 'Included': 1, 'tell': 1, 'Devices': 7, 'Ideas': 3, 'phone': 2, 'ward': 1, 'Videos': 2, 'rights': 1, 'work': 5, 'movies': 5, 'Janitorial': 1, 'foodie': 1, 'McCoist': 1, 'Bedding': 1, 'in': 42, 'Grocery': 4, 'Diaperscom': 1, 'currency': 1, 'want': 1, 'Digital': 11, 'end': 1, 'Watching': 1, 'intruders': 1, 'machine': 1, 'how': 1, 'Jungleecom': 1, 'resignation': 1, 'A': 3, 'after': 2, 'Watchlist': 2, 'purchase': 1, 'All': 7, 'Regression': 1, 'Willy': 1, 'over': 5, 'budding': 1, 'Abbott': 1, 'laser\xe2\x80\xa6': 1, 'personal': 1, 'Soapcom': 1, 'better': 3, 'Spain': 1, 'Kids': 7, 'rsaquo': 2, 'Mobile': 1, 'safe': 1, 'Analysis': 1, 'they': 1, 'Cards': 4, 'Indie': 2, 'India': 3, 'Check': 1, 'Plot': 1, 'vote': 1, '25176C': 1, 'Retina': 1, 'Wars': 1, 'content': 4, '\xd8\xb1\xd9\x88\xd8\xb2': 1, 'Lamps': 1, 'Exercise': 1, 'reader': 1, 'guitarists': 1, 'free': 7, 'Planet': 1, 'longrunning': 1, 'starts': 1, '160160160Baby': 1, 'days': 1, 'Uganda': 1, 'onto': 1, 'Swahili': 1, 'already': 1, 'features': 1, 'Working': 1, 'Please': 2, 'Cell': 2, 'Quilting': 1, 'top': 1, 'ton': 1, 'listed': 2, 'Press': 2, 'Search': 6, 'rewards': 1, 'Rare': 1, 'Converter': 2, 'serve': 1, 'took': 1, 'artistic': 1, 'karena': 1, 'bulletins': 1, 'enabled': 1, 'See': 8, 'tackled': 1, '\xe1\x80\x9b\xe1\x80\x94\xe1\x80\xba\xe1\x80\x80\xe1\x80\xaf\xe1\x80\x94\xe1\x80\xba\xe1\x80\x99\xe1\x80\xbe\xe1\x80\xac': 1, 'Sinhala': 1, 'fashion': 2, 'modern': 1, 'seen': 1, 'praising': 1, 'quotpatriotquot': 1, 'responsible': 1, 'Historic': 1, 'rides': 2, 'Wish': 5, 'Button': 1, 'Computers': 5, 'Reports': 1, 'optimized': 1, 'Vision': 1, 'Childrens': 1, 'Yoyocom': 1, 'points': 1, 'Its': 1, 'Hourly': 1, 'bomb': 2, 'Agency': 1, 'Resources': 2, 'sleuths': 1, 'Knitting': 1, 'menu': 1, 'Photography': 1, 'Game': 2, 'Free': 7, 'Orkney': 1, '\xd9\x86\xd8\xa7\xd8\xa2\xd8\xb1\xd8\xa7\xd9\x85\xdb\x8c': 1, 'do': 2, 'Account': 3, 'Netherlands': 1, 'watch': 1, 'Days': 1, 'terrors': 1, 'report': 3, 'X': 1, 'Fifa': 1, 'countries': 1, 'SymPy': 1, 'Pets': 1, 'Pet': 4, 'testing': 1, 'Formula': 1, 'Android': 7, 'John': 1, 'best': 4, 'Indonesian': 2, 'pressured': 1, 'Choice': 1, 'Water': 1, 'Controller': 1, 'Appstore': 4, 'Info': 1, 'lazy': 1, 'Notice': 1, 'Youre': 1, 'Uproar': 1, 'here': 2, 'news': 4, 'improve': 1, 'climate': 2, 'Dance': 1, 'country': 2, 'Focus': 1, 'Covers': 1, 'Computer': 2, 'games': 3, 'faces': 1, 'TVs': 1, 'Amazoncom': 9, 'Zappos': 1, 'Kerry': 2, 'puts': 1, 'Sewing': 3, 'beer': 1, 'much': 1, 'sponges': 1, 'website': 2, 'antiterror': 1, 'Scherzinger': 1, 'Voice': 1, 'Secretary': 1, 'Athletic': 1, 'Manage': 5, 'air': 2, '\xe1\x80\x9b\xe1\x80\xaf\xe1\x80\xb6\xe1\x80\xb8': 1, 'Persian': 2, 'JaynesCummings': 1, 'voice': 1, 'Wearable': 1, 'Collectibles': 3, 'Menu': 1, 'is': 7, 'it': 8, 'Mens': 1, 'ponders': 2, 'cant': 1, 'jobhunting': 1, 'Capital': 2, 'if': 2, 'Gear': 4, 'Python': 2, 'Zimbabwe': 1, '250000': 1, 'wheel': 1, 'Room': 1, 'Y': 1, 'failing': 1, 'greatest': 1, 'claims': 1, 'the': 37, 'AfterSchoolcom': 1, 'Clothing': 8, 'musical': 1, 'just': 1, 'photo': 2, 'Notebooks': 1, 'D\xc3\xa9cor': 1, '5K': 1, 'yet': 1, 'Happy' ...
# and
# and

# %% [markdown]
# ## 8. 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.

# %%
import urllib
import re #특수문자 제거를 위함

class WebWordsFrequency(list):
    dic={} #각 단어들의 출현빈도를 사전형태로 저장
    
    def __init__(self, *args):
        for ele in args:
            self.append(ele)
    def addUrl(self, url):
        self.append(url)
    def removeUrl(self, url):
        i = self.index(url) #url이 가장 먼저 나오는 인덱스 값
        self = self[:i]+self[i:]
    def listUrls(self):
        for ele in self:
            print ele
            
    #@staticmethod
    def getWordsFrequency(self):        
        if self!=None:
            for url in self:
                source = urllib.urlopen(url).read()
                len_source = len(source)

                source_new = None
                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                        found = True;
                        j = i + 7;
                        while (True):
                            if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                                #print "found - script"
                                source = source[:i] + ' ' + source[j+9:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                len_source = len(source)

                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                        found = True;
                        j = i + 6;
                        while (True):
                            if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                                #print "found - style"
                                source = source[:i] + ' ' + source[j+8:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                len_source = len(source)

                i = 0
                while (i < len_source):
                    found = False
                    if (found != True and source[i] == "<"):
                        found = True;
                        j = i + 1;
                        while (True):
                            if (source[j] == ">"):
                                #print "found - HTML tag"
                                source = source[:i] + ' ' + source[j+1:]
                                break
                            j = j + 1
                            if (j > len_source):
                                break
                        len_source = len(source)
                    i = i + 1

                words = source.split()
                
                for word in words:
                    word=re.sub('[^가-힝0-9a-zA-Z\\s]', '', word) #특수문자 제거
                    if word!='':
                        if(dic.get(word) == None):
                            dic[word] = 1
                        else:
                            dic[word] += 1
        print dic

    def getMaxFrequencyWords(self):
        max_keys=[] #value가 가장 큰 키값의 모임
        L=dic.items() #사전의 items 저장
        L.sort(reverse=True, key=lambda item:item[1]) #value값에 따라 내림차순으로 정렬
        for ele in L:
            if ele[1]==L[0][1]:
                max_keys.append(ele[0]) #내림차순 정렬을 하였으므로 첫 번째 인자가 가장 크다. 
            else: #더이상 L[0]와 같은 값이 없으면 종료
                break
        for ele in max_keys:
            print ele

class OrderedWebWordsFrequency(WebWordsFrequency):
    def getWordsFrequency(self):
        L=dic.items()
        L.sort(reverse=True, key=lambda item:item[1]) #value값에 따라 내림차순으로 정렬
        print L
        
w4 = OrderedWebWordsFrequency('http://www.nbviewer.org', 'http://www.amazon.com', 'http://www.apple.com')

w4.getWordsFrequency()
# Out:
# [('and', 56), ('in', 42), ('Amazon', 40), ('for', 40), ('to', 39), ('the', 37), ('Your', 35), ('of', 30), ('a', 30), ('your', 26), ('more', 26), ('Prime', 21), ('Video', 21), ('on', 20), ('BBC', 20), ('Kindle', 20), ('with', 18), ('TV', 18), ('Games', 17), ('The', 16), ('Books', 16), ('Fire', 15), ('Music', 15), ('Home', 14), ('Instant', 13), ('In', 13), ('With', 13), ('amp', 12), ('Digital', 11), ('News', 11), ('Shop', 11), ('or', 11), ('Baby', 11), ('nbsp', 10), ('Apps', 10), ('Sports', 10), ('For', 10), ('Accessories', 10), ('Association', 10), ('Amazoncom', 9), ('Store', 9), ('Cloud', 9), ('Apple', 9), ('Health', 8), ('See', 8), ('it', 8), ('Clothing', 8), ('Beauty', 8), ('at', 8), ('you', 8), ('Credit', 8), ('Electronics', 8), ('Devices', 7), ('All', 7), ('Kids', 7), ('free', 7), ('Free', 7), ('Android', 7), ('is', 7), ('Audible', 7), ('1', 7), ('Unlimited', 7), ('World', 7), ('browser', 7), ('5', 7), ('Gift', 7), ('More', 7), ('Movies', 7), ('from', 7), ('Get', 7), ('Us', 7), ('Search', 6), ('Drive', 6), ('Shoes', 6), ('2', 6), ('Content', 6), ('4', 6), ('How', 6), ('Supplies', 6), ('Card', 6), ('Tools', 6), ('Everything', 6), ('Watch', 5), ('new', 5), ('work', 5), ('movies', 5), ('over', 5), ('Wish', 5), ('Computers', 5), ('Manage', 5), ('Automotive', 5), ('Save', 5), ('shows', 5), ('Products', 5), ('Kitchen', 5), ('3', 5), ('Outdoors', 5), ('nbviewer', 5), ('List', 5), ('Toys', 5), ('find', 5), ('Help', 5), ('Temperature', 5), ('Deals', 5), ('Sell', 5), ('Business', 5), ('Registry', 5), ('this', 5), ('shipping', 5), ('Tablets', 5), ('out', 5), ('New', 5), ('Garden', 5), ('Industrial', 5), ('Improvement', 4), ('Items', 4), ('music', 4), ('Grocery', 4), ('Cards', 4), ('content', 4), ('Pet', 4), ('best', 4), ('Appstore', 4), ('news', 4), ('Gear', 4), ('HD', 4), ('Use', 4), ('Publishing', 4), ('Our', 4), ('View', 4), ('now', 4), ('Sign', 4), ('that', 4), ('Services', 4), ('No', 4), ('an', 4), ('Top', 4), ('6', 4), ('site', 4), ('media', 4), ('20', 4), ('Sport', 4), ('Food', 4), ('Cart', 4), ('Technology', 4), ('tablet', 4), ('Find', 4), ('be', 4), ('Entertainment', 4), ('Library', 4), ('Payment', 4), ('Scientific', 4), ('Arts', 4), ('have', 4), ('off', 4), ('Shipping', 4), ('Fashion', 4), ('UK', 4), ('books', 4), ('ever', 3), ('Made', 3), ('guide', 3), ('Privacy', 3), ('Book', 3), ('Ideas', 3), ('A', 3), ('better', 3), ('India', 3), ('Account', 3), ('report', 3), ('games', 3), ('Sewing', 3), ('Collectibles', 3), ('Try', 3), ('Wine', 3), ('Art', 3), ('right', 3), ('Gifts', 3), ('Knowledge', 3), ('0', 3), ('IPython', 3), ('may', 3), ('Radio', 3), ('not', 3), ('Asia', 3), ('city', 3), ('Grooming', 3), ('than', 3), ('10', 3), ('Web', 3), ('Shopping', 3), ('reading', 3), ('comet', 3), ('Travel', 3), ('apologises', 3), ('Jewelry', 3), ('applecom', 3), ('as', 3), ('film', 3), ('Read', 3), ('storage', 3), ('all', 3), ('Easy', 3), ('will', 3), ('experience', 3), ('Audiobooks', 3), ('7', 3), ('members', 3), ('Phones', 3), ('most', 3), ('are', 3), ('Online', 3), ('Care', 3), ('Software', 3), ('Accessibility', 3), ('Africa', 3), ('Audio', 3), ('go', 3), ('Designer', 3), ('Up', 3), ('Download', 3), ('Min', 3), ('Membership', 3), ('Outdoor', 3), ('Weather', 3), ('iPhone', 3), ('able', 3), ('Instruments', 3), ('Earth', 3), ('iPad', 3), ('Phone', 3), ('latest', 3), ('Gourmet', 3), ('executive', 3), ('Play', 3), ('US', 3), ('apps', 3), ('problem', 3), ('Pantry', 3), ('Future', 3), ('Musical', 3), ('Cases', 2), ('risk', 2), ('every', 2), ('Todays', 2), ('Available', 2), ('Culture', 2), ('Theres', 2), ('items', 2), ('24176C', 2), ('chargers', 2), ('Newsstand', 2), ('phone', 2), ('Videos', 2), ('after', 2), ('Watchlist', 2), ('rsaquo', 2), ('Indie', 2), ('Please', 2), ('Cell', 2), ('listed', 2), ('Press', 2), ('Converter', 2), ('fashion', 2), ('rides', 2), ('bomb', 2), ('Resources', 2), ('Game', 2), ('do', 2), ('Indonesian', 2), ('here', 2), ('climate', 2), ('country', 2), ('Computer', 2), ('Kerry', 2), ('website', 2), ('air', 2), ('Persian', ...

# %% [markdown]
# 소감 : 제출이 늦어서 죄송합니다. 클래스를 전체적으로 한번 둘러볼 수 있는 좋은 학습자료가 되었습니다. 감사합니다.
